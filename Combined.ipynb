# %%
#Import Dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
#Import CSV
csv_file  = "super_bowls.csv"
super_bowls_df = pd.read_csv(csv_file)
super_bowls_df.head()
# Out:
#    Year  super_bowl                  venue           city       state  \
# 0  2020          54      Hard Rock Stadium  Miami Gardens     Florida
# 1  2019          53  Mercedes-Benz Stadium        Atlanta     Georgia
# 2  2018          52      U.S. Bank Stadium    Minneapolis   Minnesota
# 3  2017          51            NRG Stadium        Houston       Texas
# 4  2016          50         Levi's Stadium    Santa Clara  California
#
#    attendance           team_winner  winning_pts      qb_winner_1 qb_winner_2  \
# 0       62417    Kansas City Chiefs           31  Patrick Mahomes         NaN
# 1       70081  New England Patriots           13        Tom Brady         NaN
# 2       67612   Philadelphia Eagles           41       Nick Foles         NaN
# 3       70807  New England Patriots           34        Tom Brady         NaN
# 4       71088        Denver Broncos           24   Peyton Manning         NaN
#
#      coach_winner            team_loser  losing_pts       qb_loser_1  \
# 0       Andy Reid   San Francisco 49ers          20  Jimmy Garoppolo
# 1  Bill Belichick      Los Angeles Rams           3       Jared Goff
# 2   Doug Pederson  New England Patriots          33        Tom Brady
# 3  Bill Belichick       Atlanta Falcons          28        Matt Ryan
# 4     Gary Kubiak     Carolina Panthers          10       Cam Newton
#
#   qb_loser_2     coach_loser  combined_pts  difference_pts
# 0        NaN   Kyle Shanahan            51              11
# 1        NaN      Sean McVay            16              10
# 2        NaN  Bill Belichick            74               8
# 3        NaN       Dan Quinn            62               6
# 4        NaN      Ron Rivera            34              14

# %%
new_super_bowls_df = super_bowls_df[['Year', 'super_bowl', 'team_winner', 'team_loser', 'attendance','qb_winner_1', 'qb_loser_1', 'coach_winner', 'coach_loser', 'combined_pts', 'difference_pts']].copy()
new_super_bowls_df.head()
# Out:
#    Year  super_bowl           team_winner            team_loser  attendance  \
# 0  2020          54    Kansas City Chiefs   San Francisco 49ers       62417
# 1  2019          53  New England Patriots      Los Angeles Rams       70081
# 2  2018          52   Philadelphia Eagles  New England Patriots       67612
# 3  2017          51  New England Patriots       Atlanta Falcons       70807
# 4  2016          50        Denver Broncos     Carolina Panthers       71088
#
#        qb_winner_1       qb_loser_1    coach_winner     coach_loser  \
# 0  Patrick Mahomes  Jimmy Garoppolo       Andy Reid   Kyle Shanahan
# 1        Tom Brady       Jared Goff  Bill Belichick      Sean McVay
# 2       Nick Foles        Tom Brady   Doug Pederson  Bill Belichick
# 3        Tom Brady        Matt Ryan  Bill Belichick       Dan Quinn
# 4   Peyton Manning       Cam Newton     Gary Kubiak      Ron Rivera
#
#    combined_pts  difference_pts
# 0            51              11
# 1            16              10
# 2            74               8
# 3            62               6
# 4            34              14

# %%
# Create a filtered dataframe from specific columns
new_super_bowls_df_cols = ["Year", "super_bowl", "team_winner", "team_loser", "attendance", "qb_winner_1", "qb_loser_1", "coach_winner", "coach_loser", "combined_pts", "difference_pts"]
new_super_bowls_df_transformed = new_super_bowls_df[new_super_bowls_df_cols].copy()

# Rename the column headers
new_super_bowls_df_transformed = new_super_bowls_df_transformed.rename(columns={"Year": "year", "qb_winner_1": "qb_winner",
                                                            "qb_loser_1": "qb_loser"})

# Clean the data by dropping duplicates and setting the index
new_super_bowls_df_transformed.drop_duplicates("year", inplace=True)
new_super_bowls_df_transformed.set_index("year", inplace=True)

new_super_bowls_df_transformed.head()
# Out:
#       super_bowl           team_winner            team_loser  attendance  \
# year
# 2020          54    Kansas City Chiefs   San Francisco 49ers       62417
# 2019          53  New England Patriots      Los Angeles Rams       70081
# 2018          52   Philadelphia Eagles  New England Patriots       67612
# 2017          51  New England Patriots       Atlanta Falcons       70807
# 2016          50        Denver Broncos     Carolina Panthers       71088
#
#             qb_winner         qb_loser    coach_winner     coach_loser  \
# year
# 2020  Patrick Mahomes  Jimmy Garoppolo       Andy Reid   Kyle Shanahan
# 2019        Tom Brady       Jared Goff  Bill Belichick      Sean McVay
# 2018       Nick Foles        Tom Brady   Doug Pederson  Bill Belichick
# 2017        Tom Brady        Matt Ryan  Bill Belichick       Dan Quinn
# 2016   Peyton Manning       Cam Newton     Gary Kubiak      Ron Rivera
#
#       combined_pts  difference_pts
# year
# 2020            51              11
# 2019            16              10
# 2018            74               8
# 2017            62               6
# 2016            34              14

# %%
#Import CSV
mvp_file  = "Name_MVP.csv"
Name_MVP_df = pd.read_csv(mvp_file)
Name_MVP_df.head()
# Out:
#    Year  Super_bowl                Winner  Winner_Pts                 Loser  \
# 0  2020          54    Kansas City Chiefs          31   San Francisco 49ers
# 1  2019          53  New England Patriots          13      Los Angeles Rams
# 2  2018          52   Philadelphia Eagles          41  New England Patriots
# 3  2017          51  New England Patriots          34       Atlanta Falcons
# 4  2016          50        Denver Broncos          24     Carolina Panthers
#
#    Loser_Pts              MVP                Stadium           City  \
# 0         20  Patrick Mahomes      Hard Rock Stadium  Miami Gardens
# 1          3   Julian Edelman  Mercedes-Benz Stadium        Atlanta
# 2         33       Nick Foles      U.S. Bank Stadium    Minneapolis
# 3         28        Tom Brady            NRG Stadium        Houston
# 4         10       Von Miller         Levi's Stadium    Santa Clara
#
#         State
# 0     Florida
# 1     Georgia
# 2   Minnesota
# 3       Texas
# 4  California

# %%
new_Name_MVP_df = Name_MVP_df[['Year', 'Super_bowl', 'MVP']].copy()
new_Name_MVP_df.head()
# Out:
#    Year  Super_bowl              MVP
# 0  2020          54  Patrick Mahomes
# 1  2019          53   Julian Edelman
# 2  2018          52       Nick Foles
# 3  2017          51        Tom Brady
# 4  2016          50       Von Miller

# %%
# Create a filtered dataframe from specific columns
new_Name_MVP_df_cols = ["Year", "Super_bowl", "MVP"]
new_Name_MVP_df_transformed = new_Name_MVP_df[new_Name_MVP_df_cols].copy()

# Rename the column headers
#new_Name_MVP_df_transformed = new_Name_MVP_df_transformed.rename(columns={"Super_bowl": "super_bowl"})

# Clean the data by dropping duplicates and setting the index
new_Name_MVP_df_transformed.drop_duplicates("Year", inplace=True)
new_Name_MVP_df_transformed.set_index("Year", inplace=True)

new_Name_MVP_df_transformed.head()
# Out:
#       Super_bowl              MVP
# Year
# 2020          54  Patrick Mahomes
# 2019          53   Julian Edelman
# 2018          52       Nick Foles
# 2017          51        Tom Brady
# 2016          50       Von Miller

# %%
rds_connection_string = "postgres:postgres@localhost:5432/sb_test"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['NAME_MVP', 'SUPER_BOWLS']

# %%
new_Name_MVP_df_transformed.to_sql(name='NAME_MVP', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# NotNullViolation                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1256                 if not evt_handled:
# -> 1257                     self.dialect.do_executemany(
#    1258                         cursor, statement, parameters, context
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# NotNullViolation: null value in column "Year" of relation "NAME_MVP" violates not-null constraint
# DETAIL:  Failing row contains (54, Patrick Mahomes, null).
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-10-145307168249> in <module>
# ----> 1 new_Name_MVP_df_transformed.to_sql(name='NAME_MVP', con=engine, if_exists='append', index=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2651         from pandas.io import sql
#    2652
# -> 2653         sql.to_sql(
#    2654             self,
#    2655             name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     510         )
#     511
# --> 512     pandas_sql.to_sql(
#     513         frame,
#     514         name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1012             )
#    1013         else:
# -> 1014             return meth(self, multiparams, params)
#    1015
#    1016     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1125             )
#    1126
# -> 1127         ret = self._execute_context(
#    1128             dialect,
#    1129             dialect.execution_ctx_cls._init_compiled,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315
#    1316         except BaseException as e:
# -> 1317             self._handle_dbapi_exception(
#    1318                 e, statement, parameters, cursor, context
#    1319             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1509                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1510             elif should_wrap:
# -> 1511                 util.raise_(
#    1512                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1513                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                             break
#    1256                 if not evt_handled:
# -> 1257                     self.dialect.do_executemany(
#    1258                         cursor, statement, parameters, context
#    1259                     )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     871     def do_executemany(self, cursor, statement, parameters, context=None):
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#     875
#
# IntegrityError: (psycopg2.errors.NotNullViolation) null value in column "Year" of relation "NAME_MVP" violates not-null constraint
# DETAIL:  Failing row contains (54, Patrick Mahomes, null).
#
# [SQL: INSERT INTO "NAME_MVP" ("Super_bowl", "MVP") VALUES (%(Super_bowl)s, %(MVP)s)]
# [parameters: ({'Super_bowl': 54, 'MVP': 'Patrick Mahomes'}, {'Super_bowl': 53, 'MVP': 'Julian Edelman'}, {'Super_bowl': 52, 'MVP': 'Nick Foles'}, {'Super_bowl': 51, 'MVP': 'Tom Brady'}, {'Super_bowl': 50, 'MVP': 'Von Miller'}, {'Super_bowl': 49, 'MVP': 'Tom Brady'}, {'Super_bowl': 48, 'MVP': 'Malcolm Smith'}, {'Super_bowl': 47, 'MVP': 'Joe Flacco'}  ... displaying 10 of 54 total bound parameter sets ...  {'Super_bowl': 2, 'MVP': 'Bart Starr+'}, {'Super_bowl': 1, 'MVP': 'Bart Starr+'})]
# (Background on this error at: http://sqlalche.me/e/13/gkpj)

# %%
new_super_bowls_df_transformed.to_sql(name='SUPER_BOWLS', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from SUPER_BOWLS', con=engine).head()
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1276                 if not evt_handled:
# -> 1277                     self.dialect.do_execute(
#    1278                         cursor, statement, parameters, context
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#
# UndefinedTable: relation "super_bowls" does not exist
# LINE 1: select * from SUPER_BOWLS
#                       ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-11-79014b5e72ec> in <module>
# ----> 1 pd.read_sql_query('select * from SUPER_BOWLS', con=engine).head()
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     324     """
#     325     pandas_sql = pandasSQL_builder(con)
# --> 326     return pandas_sql.read_query(
#     327         sql,
#     328         index_col=index_col,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1216         args = _convert_params(sql, params)
#    1217
# -> 1218         result = self.execute(*args)
#    1219         columns = result.keys()
#    1220
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1085     def execute(self, *args, **kwargs):
#    1086         """Simple passthrough to SQLAlchemy connectable"""
# -> 1087         return self.connectable.execute(*args, **kwargs)
#    1088
#    1089     def read_table(
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    2236
#    2237         connection = self._contextual_connect(close_with_result=True)
# -> 2238         return connection.execute(statement, *multiparams, **params)
#    2239
#    2240     def scalar(self, statement, *multiparams, **params):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1004         """
#    1005         if isinstance(object_, util.string_types[0]):
# -> 1006             return self._execute_text(object_, multiparams, params)
#    1007         try:
#    1008             meth = object_._execute_on_connection
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_text(self, statement, multiparams, params)
#    1173         dialect = self.dialect
#    1174         parameters = _distill_params(multiparams, params)
# -> 1175         ret = self._execute_context(
#    1176             dialect,
#    1177             dialect.execution_ctx_cls._init_statement,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315
#    1316         except BaseException as e:
# -> 1317             self._handle_dbapi_exception(
#    1318                 e, statement, parameters, cursor, context
#    1319             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1509                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1510             elif should_wrap:
# -> 1511                 util.raise_(
#    1512                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1513                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1275                             break
#    1276                 if not evt_handled:
# -> 1277                     self.dialect.do_execute(
#    1278                         cursor, statement, parameters, context
#    1279                     )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     591
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#     595     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.errors.UndefinedTable) relation "super_bowls" does not exist
# LINE 1: select * from SUPER_BOWLS
#                       ^
#
# [SQL: select * from SUPER_BOWLS]
# (Background on this error at: http://sqlalche.me/e/13/f405)
